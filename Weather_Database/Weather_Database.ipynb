# %%
# Importing dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Creating random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Creating coordinates list
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Creating nearest city list
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # Adding to nearest city list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 776

# %%
# Import the requests library.
import requests

# Import the API key.
from config2 import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=472029db9b8241d5d789332d8eb6e521

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
       
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description})
                          
                    

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | suez
# Processing Record 2 of Set 1 | clyde river
# Processing Record 3 of Set 1 | haines junction
# Processing Record 4 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 1 | oktyabrskoye
# Processing Record 6 of Set 1 | nikolayevsk-na-amure
# Processing Record 7 of Set 1 | midland
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | dwarka
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | geraldton
# Processing Record 13 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 1 | bom jesus
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | porto velho
# Processing Record 17 of Set 1 | port alfred
# Processing Record 18 of Set 1 | coihaique
# Processing Record 19 of Set 1 | vila velha
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | namatanai
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | burgeo
# Processing Record 24 of Set 1 | paamiut
# Processing Record 25 of Set 1 | vestmanna
# Processing Record 26 of Set 1 | qaanaaq
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | taoudenni
# Processing Record 29 of Set 1 | arraial do cabo
# Processing Record 30 of Set 1 | kodiak
# Processing Record 31 of Set 1 | cockburn town
# Processing Record 32 of Set 1 | gberia fotombu
# Processing Record 33 of Set 1 | saint anthony
# Processing Record 34 of Set 1 | manali
# Processing Record 35 of Set 1 | stykkisholmur
# Processing Record 36 of Set 1 | fort myers beach
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | radhanpur
# Processing Record 39 of Set 1 | butaritari
# Processing Record 40 of Set 1 | san cristobal
# Processing Record 41 of Set 1 | bluff
# Processing Record 42 of Set 1 | mahebourg
# Processing Record 43 of Set 1 | kaitangata
# Processing Record 44 of Set 1 | avarua
# Processing Record 45 of Set 1 | narrabri
# Processing Record 46 of Set 1 | kapaa
# Processing Record 47 of Set 1 | puerto ayora
# Processing Record 48 of Set 1 | kudahuvadhoo
# Processing Record 49 of Set 1 | saint-philippe
# Processing Record 50 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 2 | genc
# Processing Record 2 of Set 2 | engenheiro beltrao
# Processing Record 3 of Set 2 | baykit
# Processing Record 4 of Set 2 | honiara
# Processing Record 5 of Set 2 | bathsheba
# Processing Record 6 of Set 2 | punta arenas
# Processing Record 7 of Set 2 | madimba
# Processing Record 8 of Set 2 | vrangel
# Processing Record 9 of Set 2 | pisco
# Processing Record 10 of Set 2 | trairi
# Processing Record 11 of Set 2 | bestobe
# Processing Record 12 of Set 2 | taltal
# Processing Record 13 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 2 | provideniya
# Processing Record 15 of Set 2 | tommot
# Processing Record 16 of Set 2 | yellowknife
# Processing Record 17 of Set 2 | hithadhoo
# Processing Record 18 of Set 2 | cherskiy
# Processing Record 19 of Set 2 | barrow
# Processing Record 20 of Set 2 | labuhan
# Processing Record 21 of Set 2 | luderitz
# Processing Record 22 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 2 | pyinmana
# Processing Record 25 of Set 2 | kahului
# Processing Record 26 of Set 2 | kabinda
# Processing Record 27 of Set 2 | okhotsk
# Processing Record 28 of Set 2 | san ramon
# Processing Record 29 of Set 2 | castro
# Processing Record 30 of Set 2 | tasiilaq
# Processing Record 31 of Set 2 | aracruz
# Processing Record 32 of Set 2 | kungurtug
# Processing Record 33 of Set 2 | wasilla
# Processing Record 34 of Set 2 | vila
# Processing Record 35 of Set 2 | santander jimenez
# Processing Record 36 of Set 2 | san patricio
# Processing Record 37 of Set 2 | port-de-paix
# City not found. Skipping...
# Processing Record 38 of Set 2 | mersing
# Processing Record 39 of Set 2 | lorengau
# Processing Record 40 of Set 2 | laguna
# Processing Record 41 of Set 2 | fort saint john
# City not found. Skipping...
# Processing Record 42 of Set 2 | coquimbo
# Processing Record 43 of Set 2 | pangnirtung
# Processing Record 44 of Set 2 | sarandi
# Processing Record 45 of Set 2 | nanortalik
# Processing Record 46 of Set 2 | camacha
# Processing Record 47 of Set 2 | atambua
# Processing Record 48 of Set 2 | lanigan
# Processing Record 49 of Set 2 | tiksi
# Processing Record 50 of Set 2 | chokurdakh
# Processing Record 1 of Set 3 | ribeira grande
# Processing Record 2 of Set 3 | kovernino
# Processing Record 3 of Set 3 | saskylakh
# Processing Record 4 of Set 3 | porec
# Processing Record 5 of Set 3 | coos bay
# Processing Record 6 of Set 3 | lagoa
# Processing Record 7 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 8 of Set 3 | jieshou
# Processing Record 9 of Set 3 | garissa
# Processing Record 10 of Set 3 | douglas
# Processing Record 11 of Set 3 | mudgee
# Processing Record 12 of Set 3 | tuatapere
# Processing Record 13 of Set 3 | teahupoo
# Processing Record 14 of Set 3 | luis correia
# Processing Record 15 of Set 3 | adrar
# Processing Record 16 of Set 3 | airai
# Processing Record 17 of Set 3 | lebu
# Processing Record 18 of Set 3 | pyapon
# Processing Record 19 of Set 3 | norman wells
# Processing Record 20 of Set 3 | half moon bay
# Processing Record 21 of Set 3 | qaqortoq
# Processing Record 22 of Set 3 | mandali
# Processing Record 23 of Set 3 | honningsvag
# Processing Record 24 of Set 3 | ponta do sol
# Processing Record 25 of Set 3 | nikolskoye
# Processing Record 26 of Set 3 | bichena
# Processing Record 27 of Set 3 | tuktoyaktuk
# Processing Record 28 of Set 3 | poum
# Processing Record 29 of Set 3 | portland
# Processing Record 30 of Set 3 | barillas
# Processing Record 31 of Set 3 | neuquen
# Processing Record 32 of Set 3 | rundu
# Processing Record 33 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 3 | atuona
# Processing Record 35 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 3 | umm kaddadah
# Processing Record 37 of Set 3 | ingham
# Processing Record 38 of Set 3 | tocopilla
# Processing Record 39 of Set 3 | kachiry
# Processing Record 40 of Set 3 | esperance
# Processing Record 41 of Set 3 | yichang
# Processing Record 42 of Set 3 | chuy
# Processing Record 43 of Set 3 | east london
# Processing Record 44 of Set 3 | viedma
# Processing Record 45 of Set 3 | deh rawud
# City not found. Skipping...
# Processing Record 46 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 47 of Set 3 | tezu
# Processing Record 48 of Set 3 | marsh harbour
# Processing Record 49 of Set 3 | hovd
# Processing Record 50 of Set 3 | vermilion
# Processing Record 1 of Set 4 | gannan
# Processing Record 2 of Set 4 | qui nhon
# Processing Record 3 of Set 4 | bethel
# Processing Record 4 of Set 4 | naze
# Processing Record 5 of Set 4 | cabo san lucas
# Processing Record 6 of Set 4 | vanavara
# Processing Record 7 of Set 4 | huarmey
# Processing Record 8 of Set 4 | fort-shevchenko
# Processing Record 9 of Set 4 | oranjestad
# Processing Record 10 of Set 4 | victoria
# Processing Record 11 of Set 4 | coari
# Processing Record 12 of Set 4 | camp verde
# Processing Record 13 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 15 of Set 4 | padang
# Processing Record 16 of Set 4 | khvoynaya
# Processing Record 17 of Set 4 | asau
# Processing Record 18 of Set 4 | hidrolandia
# Processing Record 19 of Set 4 | garowe
# Processing Record 20 of Set 4 | saldanha
# Processing Record 21 of Set 4 | faya
# Processing Record 22 of Set 4 | pimentel
# Processing Record 23 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 4 | bandarbeyla
# Processing Record 25 of Set 4 | hobart
# Processing Record 26 of Set 4 | touros
# Processing Record 27 of Set 4 | tomatlan
# Processing Record 28 of Set 4 | kedrovyy
# Processing Record 29 of Set 4 | mizdah
# Processing Record 30 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 4 | floro
# Processing Record 32 of Set 4 | biltine
# Processing Record 33 of Set 4 | kavaratti
# Processing Record 34 of Set 4 | hualmay
# Processing Record 35 of Set 4 | pasni
# Processing Record 36 of Set 4 | jujuy
# City not found. Skipping...
# Processing Record 37 of Set 4 | vulcan
# Processing Record 38 of Set 4 | ouango
# Processing Record 39 of Set 4 | iranshahr
# Processing Record 40 of Set 4 | vao
# Processing Record 41 of Set 4 | salalah
# Processing Record 42 of Set 4 | surt
# Processing Record 43 of Set 4 | cidreira
# Processing Record 44 of Set 4 | jiroft
# City not found. Skipping...
# Processing Record 45 of Set 4 | genhe
# Processing Record 46 of Set 4 | gold coast
# Processing Record 47 of Set 4 | high level
# Processing Record 48 of Set 4 | hasaki
# Processing Record 49 of Set 4 | ramanuj ganj
# Processing Record 50 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 5 | tamiahua
# Processing Record 2 of Set 5 | torbat-e jam
# Processing Record 3 of Set 5 | port macquarie
# Processing Record 4 of Set 5 | port shepstone
# Processing Record 5 of Set 5 | vardo
# Processing Record 6 of Set 5 | kaputa
# Processing Record 7 of Set 5 | khatanga
# Processing Record 8 of Set 5 | fairbanks
# Processing Record 9 of Set 5 | muros
# Processing Record 10 of Set 5 | rawson
# Processing Record 11 of Set 5 | new norfolk
# Processing Record 12 of Set 5 | margate
# Processing Record 13 of Set 5 | okha
# Processing Record 14 of Set 5 | tura
# Processing Record 15 of Set 5 | praia da vitoria
# Processing Record 16 of Set 5 | wajid
# Processing Record 17 of Set 5 | beloha
# Processing Record 18 of Set 5 | port hardy
# Processing Record 19 of Set 5 | whitehorse
# Processing Record 20 of Set 5 | port-gentil
# Processing Record 21 of Set 5 | tallahassee
# Processing Record 22 of Set 5 | martapura
# Processing Record 23 of Set 5 | aguimes
# Processing Record 24 of Set 5 | soloneshnoye
# Processing Record 25 of Set 5 | tarbagatay
# Processing Record 26 of Set 5 | temiscaming
# Processing Record 27 of Set 5 | mar del plata
# Processing Record 28 of Set 5 | elliot lake
# Processing Record 29 of Set 5 | lakes entrance
# Processing Record 30 of Set 5 | mitsamiouli
# Processing Record 31 of Set 5 | medea
# Processing Record 32 of Set 5 | acapulco
# Processing Record 33 of Set 5 | klaksvik
# Processing Record 34 of Set 5 | ilhabela
# Processing Record 35 of Set 5 | saint george
# Processing Record 36 of Set 5 | bria
# Processing Record 37 of Set 5 | ketchikan
# Processing Record 38 of Set 5 | upernavik
# Processing Record 39 of Set 5 | longyearbyen
# Processing Record 40 of Set 5 | gobabis
# Processing Record 41 of Set 5 | georgetown
# Processing Record 42 of Set 5 | yumen
# Processing Record 43 of Set 5 | kitimat
# Processing Record 44 of Set 5 | aklavik
# Processing Record 45 of Set 5 | arlit
# Processing Record 46 of Set 5 | pokhara
# Processing Record 47 of Set 5 | yuzhno-kurilsk
# Processing Record 48 of Set 5 | bilibino
# Processing Record 49 of Set 5 | henties bay
# Processing Record 50 of Set 5 | jamestown
# Processing Record 1 of Set 6 | katsuura
# Processing Record 2 of Set 6 | merauke
# Processing Record 3 of Set 6 | kulhudhuffushi
# Processing Record 4 of Set 6 | yerbogachen
# Processing Record 5 of Set 6 | kalmunai
# Processing Record 6 of Set 6 | sengiley
# Processing Record 7 of Set 6 | durban
# Processing Record 8 of Set 6 | tabou
# Processing Record 9 of Set 6 | northam
# Processing Record 10 of Set 6 | sorong
# Processing Record 11 of Set 6 | taburi
# City not found. Skipping...
# Processing Record 12 of Set 6 | quatre cocos
# Processing Record 13 of Set 6 | sabana de torres
# Processing Record 14 of Set 6 | linxia
# Processing Record 15 of Set 6 | omsukchan
# Processing Record 16 of Set 6 | port blair
# Processing Record 17 of Set 6 | panjakent
# Processing Record 18 of Set 6 | novyy urengoy
# Processing Record 19 of Set 6 | diego de almagro
# Processing Record 20 of Set 6 | hamilton
# Processing Record 21 of Set 6 | jiwani
# Processing Record 22 of Set 6 | mukhen
# Processing Record 23 of Set 6 | souillac
# Processing Record 24 of Set 6 | naples
# Processing Record 25 of Set 6 | lompoc
# Processing Record 26 of Set 6 | sao raimundo das mangabeiras
# Processing Record 27 of Set 6 | aykhal
# Processing Record 28 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 29 of Set 6 | bubaque
# Processing Record 30 of Set 6 | ouadda
# Processing Record 31 of Set 6 | vaitape
# Processing Record 32 of Set 6 | ailigandi
# Processing Record 33 of Set 6 | buraydah
# Processing Record 34 of Set 6 | dikson
# Processing Record 35 of Set 6 | wanxian
# Processing Record 36 of Set 6 | college
# Processing Record 37 of Set 6 | pathein
# Processing Record 38 of Set 6 | constitucion
# Processing Record 39 of Set 6 | ballina
# Processing Record 40 of Set 6 | alamosa
# Processing Record 41 of Set 6 | polis
# Processing Record 42 of Set 6 | acarau
# Processing Record 43 of Set 6 | mangrol
# Processing Record 44 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 6 | ambunti
# Processing Record 46 of Set 6 | juxtlahuaca
# Processing Record 47 of Set 6 | evanston
# Processing Record 48 of Set 6 | palana
# Processing Record 49 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 50 of Set 6 | fevralsk
# City not found. Skipping...
# Processing Record 1 of Set 7 | hilo
# Processing Record 2 of Set 7 | lastoursville
# Processing Record 3 of Set 7 | thinadhoo
# Processing Record 4 of Set 7 | kruisfontein
# Processing Record 5 of Set 7 | barra do corda
# Processing Record 6 of Set 7 | la ronge
# Processing Record 7 of Set 7 | chara
# Processing Record 8 of Set 7 | saint-raphael
# Processing Record 9 of Set 7 | caravelas
# Processing Record 10 of Set 7 | guerrero negro
# Processing Record 11 of Set 7 | kimbe
# Processing Record 12 of Set 7 | roma
# Processing Record 13 of Set 7 | great yarmouth
# Processing Record 14 of Set 7 | chulumani
# Processing Record 15 of Set 7 | karamea
# City not found. Skipping...
# Processing Record 16 of Set 7 | yar-sale
# Processing Record 17 of Set 7 | kaabong
# Processing Record 18 of Set 7 | urdoma
# Processing Record 19 of Set 7 | morondava
# Processing Record 20 of Set 7 | liberal
# Processing Record 21 of Set 7 | bambous virieux
# Processing Record 22 of Set 7 | te anau
# Processing Record 23 of Set 7 | richards bay
# Processing Record 24 of Set 7 | taseyevo
# Processing Record 25 of Set 7 | berlevag
# Processing Record 26 of Set 7 | oda
# Processing Record 27 of Set 7 | acaponeta
# Processing Record 28 of Set 7 | naifaru
# Processing Record 29 of Set 7 | samarai
# Processing Record 30 of Set 7 | pangkalanbuun
# Processing Record 31 of Set 7 | matadi
# Processing Record 32 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 33 of Set 7 | port elizabeth
# Processing Record 34 of Set 7 | ashington
# Processing Record 35 of Set 7 | paso de carrasco
# Processing Record 36 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 37 of Set 7 | kavieng
# Processing Record 38 of Set 7 | san quintin
# Processing Record 39 of Set 7 | ilulissat
# Processing Record 40 of Set 7 | bocaiuva
# Processing Record 41 of Set 7 | wadi musa
# Processing Record 42 of Set 7 | srednekolymsk
# Processing Record 43 of Set 7 | wagar
# Processing Record 44 of Set 7 | homer
# Processing Record 45 of Set 7 | sisimiut
# Processing Record 46 of Set 7 | slave lake
# Processing Record 47 of Set 7 | tabialan
# City not found. Skipping...
# Processing Record 48 of Set 7 | baiao
# Processing Record 49 of Set 7 | sobolevo
# Processing Record 50 of Set 7 | severo-yeniseyskiy
# Processing Record 1 of Set 8 | bajah
# Processing Record 2 of Set 8 | shenjiamen
# Processing Record 3 of Set 8 | mangan
# Processing Record 4 of Set 8 | aitape
# Processing Record 5 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 6 of Set 8 | irece
# Processing Record 7 of Set 8 | sikandarabad
# Processing Record 8 of Set 8 | myitkyina
# Processing Record 9 of Set 8 | tubmanburg
# Processing Record 10 of Set 8 | haapiti
# Processing Record 11 of Set 8 | solovetskiy
# City not found. Skipping...
# Processing Record 12 of Set 8 | carnarvon
# Processing Record 13 of Set 8 | ewa beach
# Processing Record 14 of Set 8 | nome
# Processing Record 15 of Set 8 | bredasdorp
# Processing Record 16 of Set 8 | sakaiminato
# Processing Record 17 of Set 8 | sao jose da coroa grande
# Processing Record 18 of Set 8 | baie-saint-paul
# Processing Record 19 of Set 8 | rameswaram
# Processing Record 20 of Set 8 | balikpapan
# Processing Record 21 of Set 8 | lazaro cardenas
# Processing Record 22 of Set 8 | general roca
# Processing Record 23 of Set 8 | westport
# Processing Record 24 of Set 8 | atasu
# Processing Record 25 of Set 8 | mount gambier
# Processing Record 26 of Set 8 | mumford
# Processing Record 27 of Set 8 | oranjemund
# Processing Record 28 of Set 8 | ormara
# Processing Record 29 of Set 8 | dingle
# Processing Record 30 of Set 8 | grindavik
# Processing Record 31 of Set 8 | hongjiang
# Processing Record 32 of Set 8 | jalu
# Processing Record 33 of Set 8 | thompson
# Processing Record 34 of Set 8 | belmonte
# Processing Record 35 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 36 of Set 8 | vavoua
# Processing Record 37 of Set 8 | afmadu
# City not found. Skipping...
# Processing Record 38 of Set 8 | kitui
# Processing Record 39 of Set 8 | calabozo
# Processing Record 40 of Set 8 | paragould
# Processing Record 41 of Set 8 | stejari
# Processing Record 42 of Set 8 | kailua
# Processing Record 43 of Set 8 | sackville
# Processing Record 44 of Set 8 | maniago
# Processing Record 45 of Set 8 | itoman
# Processing Record 46 of Set 8 | koutsouras
# Processing Record 47 of Set 8 | faanui
# Processing Record 48 of Set 8 | arklow
# Processing Record 49 of Set 8 | rosetta
# Processing Record 50 of Set 8 | meulaboh
# Processing Record 1 of Set 9 | juneau
# Processing Record 2 of Set 9 | impfondo
# Processing Record 3 of Set 9 | torbay
# Processing Record 4 of Set 9 | ambon
# Processing Record 5 of Set 9 | spokoynaya
# Processing Record 6 of Set 9 | port lincoln
# Processing Record 7 of Set 9 | nouakchott
# Processing Record 8 of Set 9 | cortez
# Processing Record 9 of Set 9 | berbera
# Processing Record 10 of Set 9 | colares
# Processing Record 11 of Set 9 | newport
# Processing Record 12 of Set 9 | vila franca do campo
# Processing Record 13 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 9 | bengkulu
# Processing Record 15 of Set 9 | don sak
# Processing Record 16 of Set 9 | talnakh
# Processing Record 17 of Set 9 | macklin
# Processing Record 18 of Set 9 | kysyl-syr
# Processing Record 19 of Set 9 | hauterive
# Processing Record 20 of Set 9 | udachnyy
# Processing Record 21 of Set 9 | leua
# Processing Record 22 of Set 9 | aswan
# Processing Record 23 of Set 9 | lizzano
# Processing Record 24 of Set 9 | sinnamary
# Processing Record 25 of Set 9 | stornoway
# Processing Record 26 of Set 9 | malakal
# Processing Record 27 of Set 9 | batemans bay
# Processing Record 28 of Set 9 | adre
# Processing Record 29 of Set 9 | mount isa
# Processing Record 30 of Set 9 | luanda
# Processing Record 31 of Set 9 | lawan kuda baharu
# City not found. Skipping...
# Processing Record 32 of Set 9 | koungou
# Processing Record 33 of Set 9 | sydney mines
# Processing Record 34 of Set 9 | megion
# Processing Record 35 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 36 of Set 9 | plouzane
# Processing Record 37 of Set 9 | san carlos del zulia
# Processing Record 38 of Set 9 | poso
# Processing Record 39 of Set 9 | deep river
# Processing Record 40 of Set 9 | porto novo
# Processing Record 41 of Set 9 | krasnoselkup
# Processing Record 42 of Set 9 | nabire
# Processing Record 43 of Set 9 | shubarshi
# Processing Record 44 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 9 | venkatagiri
# Processing Record 46 of Set 9 | karakendzha
# City not found. Skipping...
# Processing Record 47 of Set 9 | lasem
# Processing Record 48 of Set 9 | hammerfest
# Processing Record 49 of Set 9 | turbat
# Processing Record 50 of Set 9 | neiafu
# Processing Record 1 of Set 10 | san luis potosi
# Processing Record 2 of Set 10 | severo-kurilsk
# Processing Record 3 of Set 10 | mildura
# Processing Record 4 of Set 10 | sibut
# Processing Record 5 of Set 10 | kusk
# City not found. Skipping...
# Processing Record 6 of Set 10 | chippewa falls
# Processing Record 7 of Set 10 | laela
# Processing Record 8 of Set 10 | kastamonu
# Processing Record 9 of Set 10 | aldan
# Processing Record 10 of Set 10 | iqaluit
# Processing Record 11 of Set 10 | keti bandar
# Processing Record 12 of Set 10 | green river
# Processing Record 13 of Set 10 | the valley
# Processing Record 14 of Set 10 | do gonbadan
# Processing Record 15 of Set 10 | amatlan
# City not found. Skipping...
# Processing Record 16 of Set 10 | mae hong son
# Processing Record 17 of Set 10 | two hills
# Processing Record 18 of Set 10 | la gaulette
# City not found. Skipping...
# Processing Record 19 of Set 10 | baruun-urt
# Processing Record 20 of Set 10 | saint-pierre
# Processing Record 21 of Set 10 | huilong
# Processing Record 22 of Set 10 | beira
# Processing Record 23 of Set 10 | damghan
# Processing Record 24 of Set 10 | howard springs
# Processing Record 25 of Set 10 | yangjiang
# Processing Record 26 of Set 10 | ambilobe
# Processing Record 27 of Set 10 | port moresby
# Processing Record 28 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 10 | alghero
# Processing Record 30 of Set 10 | bambanglipuro
# Processing Record 31 of Set 10 | skjervoy
# Processing Record 32 of Set 10 | pauini
# Processing Record 33 of Set 10 | santo tomas
# Processing Record 34 of Set 10 | chapais
# Processing Record 35 of Set 10 | zyryanka
# Processing Record 36 of Set 10 | mao
# Processing Record 37 of Set 10 | chaoyang
# Processing Record 38 of Set 10 | mehamn
# Processing Record 39 of Set 10 | imeni poliny osipenko
# Processing Record 40 of Set 10 | andenes
# Processing Record 41 of Set 10 | polson
# Processing Record 42 of Set 10 | san carlos de bariloche
# Processing Record 43 of Set 10 | southbridge
# Processing Record 44 of Set 10 | san andres
# Processing Record 45 of Set 10 | gagnoa
# Processing Record 46 of Set 10 | yarada
# Processing Record 47 of Set 10 | tautira
# Processing Record 48 of Set 10 | lavrentiya
# Processing Record 49 of Set 10 | mata
# Processing Record 50 of Set 10 | muhos
# Processing Record 1 of Set 11 | fortuna
# Processing Record 2 of Set 11 | port augusta
# Processing Record 3 of Set 11 | havelock
# Processing Record 4 of Set 11 | sorland
# Processing Record 5 of Set 11 | dicabisagan
# Processing Record 6 of Set 11 | bella union
# Processing Record 7 of Set 11 | tilichiki
# Processing Record 8 of Set 11 | cairns
# Processing Record 9 of Set 11 | fuengirola
# Processing Record 10 of Set 11 | leningradskiy
# Processing Record 11 of Set 11 | puerto escondido
# Processing Record 12 of Set 11 | diffa
# Processing Record 13 of Set 11 | codrington
# Processing Record 14 of Set 11 | anadyr
# Processing Record 15 of Set 11 | mana
# Processing Record 16 of Set 11 | rio grande
# Processing Record 17 of Set 11 | banda aceh
# Processing Record 18 of Set 11 | toamasina
# Processing Record 19 of Set 11 | brae
# Processing Record 20 of Set 11 | maarianhamina
# Processing Record 21 of Set 11 | ahuimanu
# Processing Record 22 of Set 11 | auki
# Processing Record 23 of Set 11 | idil
# Processing Record 24 of Set 11 | nemuro
# Processing Record 25 of Set 11 | banjar
# Processing Record 26 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 11 | yaan
# Processing Record 28 of Set 11 | mersin
# Processing Record 29 of Set 11 | broome
# Processing Record 30 of Set 11 | khowai
# Processing Record 31 of Set 11 | kijang
# Processing Record 32 of Set 11 | marrakesh
# Processing Record 33 of Set 11 | zuwarah
# Processing Record 34 of Set 11 | kajaani
# Processing Record 35 of Set 11 | valkla
# Processing Record 36 of Set 11 | along
# Processing Record 37 of Set 11 | constantine
# Processing Record 38 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 39 of Set 11 | nyzhnya krynka
# Processing Record 40 of Set 11 | daru
# Processing Record 41 of Set 11 | shimoda
# Processing Record 42 of Set 11 | prince rupert
# Processing Record 43 of Set 11 | panguna
# Processing Record 44 of Set 11 | banaue
# Processing Record 45 of Set 11 | millville
# Processing Record 46 of Set 11 | sao filipe
# Processing Record 47 of Set 11 | shambu
# Processing Record 48 of Set 11 | cordele
# Processing Record 49 of Set 11 | patpata
# City not found. Skipping...
# Processing Record 50 of Set 11 | alihe
# Processing Record 1 of Set 12 | ciego de avila
# Processing Record 2 of Set 12 | crailsheim
# Processing Record 3 of Set 12 | iquique
# Processing Record 4 of Set 12 | hambantota
# Processing Record 5 of Set 12 | njinikom
# Processing Record 6 of Set 12 | sitka
# Processing Record 7 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 12 | waimana
# Processing Record 9 of Set 12 | sainte-marie
# Processing Record 10 of Set 12 | tiarei
# Processing Record 11 of Set 12 | palembang
# Processing Record 12 of Set 12 | grand gaube
# Processing Record 13 of Set 12 | benidorm
# Processing Record 14 of Set 12 | nokaneng
# Processing Record 15 of Set 12 | berdigestyakh
# Processing Record 16 of Set 12 | eureka
# Processing Record 17 of Set 12 | cape canaveral
# Processing Record 18 of Set 12 | latung
# Processing Record 19 of Set 12 | aquiraz
# Processing Record 20 of Set 12 | aban
# Processing Record 21 of Set 12 | santa marta
# Processing Record 22 of Set 12 | makinsk
# Processing Record 23 of Set 12 | nyurba
# Processing Record 24 of Set 12 | manoel urbano
# Processing Record 25 of Set 12 | necochea
# Processing Record 26 of Set 12 | coahuayana
# Processing Record 27 of Set 12 | akureyri
# Processing Record 28 of Set 12 | jian
# Processing Record 29 of Set 12 | peniche
# Processing Record 30 of Set 12 | xinzhi
# Processing Record 31 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 12 | zapolyarnyy
# Processing Record 33 of Set 12 | oksfjord
# Processing Record 34 of Set 12 | dukhovnitskoye
# Processing Record 35 of Set 12 | tukrah
# Processing Record 36 of Set 12 | freeport
# Processing Record 37 of Set 12 | ziro
# Processing Record 38 of Set 12 | leshukonskoye
# Processing Record 39 of Set 12 | fukue
# Processing Record 40 of Set 12 | comodoro rivadavia
# Processing Record 41 of Set 12 | havoysund
# Processing Record 42 of Set 12 | flinders
# Processing Record 43 of Set 12 | sarkand
# Processing Record 44 of Set 12 | pascagoula
# Processing Record 45 of Set 12 | santa cruz del sur
# Processing Record 46 of Set 12 | gainesville
# Processing Record 47 of Set 12 | veinticinco de mayo
# Processing Record 48 of Set 12 | maputo
# Processing Record 49 of Set 12 | azul
# Processing Record 50 of Set 12 | khalabat
# Processing Record 1 of Set 13 | pulandian
# Processing Record 2 of Set 13 | ostrovnoy
# Processing Record 3 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 4 of Set 13 | golden
# Processing Record 5 of Set 13 | xacmaz
# Processing Record 6 of Set 13 | macamic
# Processing Record 7 of Set 13 | pontianak
# Processing Record 8 of Set 13 | obidos
# Processing Record 9 of Set 13 | bandrele
# Processing Record 10 of Set 13 | yanam
# Processing Record 11 of Set 13 | banon
# Processing Record 12 of Set 13 | jumla
# Processing Record 13 of Set 13 | isangel
# Processing Record 14 of Set 13 | ibra
# Processing Record 15 of Set 13 | la macarena
# Processing Record 16 of Set 13 | laukaa
# Processing Record 17 of Set 13 | umea
# Processing Record 18 of Set 13 | alcaudete
# Processing Record 19 of Set 13 | kalmar
# Processing Record 20 of Set 13 | quelimane
# Processing Record 21 of Set 13 | zhigansk
# Processing Record 22 of Set 13 | mchinji
# Processing Record 23 of Set 13 | narsaq
# Processing Record 24 of Set 13 | orotukan
# Processing Record 25 of Set 13 | birao
# Processing Record 26 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 27 of Set 13 | pevek
# Processing Record 28 of Set 13 | caxias
# Processing Record 29 of Set 13 | gumdag
# Processing Record 30 of Set 13 | upata
# Processing Record 31 of Set 13 | netarhat
# Processing Record 32 of Set 13 | sangmelima
# Processing Record 33 of Set 13 | svetlogorsk
# Processing Record 34 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 13 | kargasok
# Processing Record 36 of Set 13 | belyy yar
# Processing Record 37 of Set 13 | sasovo
# Processing Record 38 of Set 13 | borogontsy
# Processing Record 39 of Set 13 | barroualie
# City not found. Skipping...
# Processing Record 40 of Set 13 | hailey
# Processing Record 41 of Set 13 | inhambane
# Processing Record 42 of Set 13 | ried
# Processing Record 43 of Set 13 | ayan
# Processing Record 44 of Set 13 | maniitsoq
# Processing Record 45 of Set 13 | edirne
# Processing Record 46 of Set 13 | askiz
# Processing Record 47 of Set 13 | kayanga
# Processing Record 48 of Set 13 | la romana
# Processing Record 49 of Set 13 | puerto carreno
# Processing Record 50 of Set 13 | shingu
# Processing Record 1 of Set 14 | halifax
# Processing Record 2 of Set 14 | polignano a mare
# Processing Record 3 of Set 14 | vestmannaeyjar
# Processing Record 4 of Set 14 | tlapehuala
# Processing Record 5 of Set 14 | tain
# Processing Record 6 of Set 14 | mwinilunga
# Processing Record 7 of Set 14 | nueve de julio
# Processing Record 8 of Set 14 | talara
# Processing Record 9 of Set 14 | alice springs
# Processing Record 10 of Set 14 | manzhouli
# Processing Record 11 of Set 14 | namibe
# Processing Record 12 of Set 14 | geresk
# City not found. Skipping...
# Processing Record 13 of Set 14 | mogadishu
# Processing Record 14 of Set 14 | trujillo
# Processing Record 15 of Set 14 | katangli
# Processing Record 16 of Set 14 | kerki
# City not found. Skipping...
# Processing Record 17 of Set 14 | abalak
# Processing Record 18 of Set 14 | ongandjera
# Processing Record 19 of Set 14 | ponta delgada
# Processing Record 20 of Set 14 | broken hill
# Processing Record 21 of Set 14 | cabedelo
# Processing Record 22 of Set 14 | olafsvik
# Processing Record 23 of Set 14 | zhuravky
# Processing Record 24 of Set 14 | hofn
# Processing Record 25 of Set 14 | walla walla
# Processing Record 26 of Set 14 | kuandian
# Processing Record 27 of Set 14 | muli
# Processing Record 28 of Set 14 | namtsy
# Processing Record 29 of Set 14 | zonguldak
# Processing Record 30 of Set 14 | cabras
# Processing Record 31 of Set 14 | klamath falls
# Processing Record 32 of Set 14 | tegal
# Processing Record 33 of Set 14 | tripoli
# Processing Record 34 of Set 14 | spornoye
# Processing Record 35 of Set 14 | port hedland
# Processing Record 36 of Set 14 | vayalar
# Processing Record 37 of Set 14 | hervey bay
# Processing Record 38 of Set 14 | puerto narino
# Processing Record 39 of Set 14 | steamboat springs
# Processing Record 40 of Set 14 | kenora
# Processing Record 41 of Set 14 | tual
# Processing Record 42 of Set 14 | bianzhuang
# Processing Record 43 of Set 14 | aasiaat
# Processing Record 44 of Set 14 | yulara
# Processing Record 45 of Set 14 | tymovskoye
# Processing Record 46 of Set 14 | xichang
# Processing Record 47 of Set 14 | progress
# Processing Record 48 of Set 14 | ancud
# Processing Record 49 of Set 14 | fare
# Processing Record 50 of Set 14 | hajiganj
# Processing Record 1 of Set 15 | outlook
# Processing Record 2 of Set 15 | springbok
# Processing Record 3 of Set 15 | dakoro
# Processing Record 4 of Set 15 | barra patuca
# Processing Record 5 of Set 15 | la maddalena
# Processing Record 6 of Set 15 | benicarlo
# Processing Record 7 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 8 of Set 15 | maningrida
# Processing Record 9 of Set 15 | teya
# Processing Record 10 of Set 15 | ust-ilimsk
# Processing Record 11 of Set 15 | santiago
# Processing Record 12 of Set 15 | kinlochleven
# Processing Record 13 of Set 15 | fort nelson
# Processing Record 14 of Set 15 | yeppoon
# Processing Record 15 of Set 15 | monrovia
# Processing Record 16 of Set 15 | nantucket
# Processing Record 17 of Set 15 | hastings
# Processing Record 18 of Set 15 | muisne
# Processing Record 19 of Set 15 | zhaotong
# Processing Record 20 of Set 15 | szczytno
# Processing Record 21 of Set 15 | kidal
# Processing Record 22 of Set 15 | libertador general san martin
# Processing Record 23 of Set 15 | dudinka
# Processing Record 24 of Set 15 | sand
# Processing Record 25 of Set 15 | timmins
# Processing Record 26 of Set 15 | palmer
# Processing Record 27 of Set 15 | san jose
# Processing Record 28 of Set 15 | marabba
# Processing Record 29 of Set 15 | anyksciai
# Processing Record 30 of Set 15 | kalemie
# Processing Record 31 of Set 15 | korla
# Processing Record 32 of Set 15 | ipojuca
# Processing Record 33 of Set 15 | shenzhen
# Processing Record 34 of Set 15 | oussouye
# Processing Record 35 of Set 15 | rocha
# Processing Record 36 of Set 15 | barcelos
# Processing Record 37 of Set 15 | catamarca
# Processing Record 38 of Set 15 | sioux lookout
# Processing Record 39 of Set 15 | koumac
# Processing Record 40 of Set 15 | aksu
# Processing Record 41 of Set 15 | tayu
# Processing Record 42 of Set 15 | enid
# Processing Record 43 of Set 15 | susanino
# Processing Record 44 of Set 15 | menzelinsk
# Processing Record 45 of Set 15 | altamont
# Processing Record 46 of Set 15 | salyan
# Processing Record 47 of Set 15 | pampierstad
# Processing Record 48 of Set 15 | hami
# Processing Record 49 of Set 15 | jalesar
# Processing Record 50 of Set 15 | luxor
# Processing Record 1 of Set 16 | moron
# Processing Record 2 of Set 16 | ciudad guayana
# Processing Record 3 of Set 16 | marawi
# Processing Record 4 of Set 16 | bac lieu
# Processing Record 5 of Set 16 | beringovskiy
# Processing Record 6 of Set 16 | villa carlos paz
# Processing Record 7 of Set 16 | roald
# Processing Record 8 of Set 16 | male
# Processing Record 9 of Set 16 | sambava
# Processing Record 10 of Set 16 | husavik
# Processing Record 11 of Set 16 | kapit
# Processing Record 12 of Set 16 | satitoa
# City not found. Skipping...
# Processing Record 13 of Set 16 | watertown
# Processing Record 14 of Set 16 | marinette
# Processing Record 15 of Set 16 | bonthe
# Processing Record 16 of Set 16 | burica
# City not found. Skipping...
# Processing Record 17 of Set 16 | ovalle
# Processing Record 18 of Set 16 | jackson
# Processing Record 19 of Set 16 | bayshore gardens
# Processing Record 20 of Set 16 | salvador
# Processing Record 21 of Set 16 | karratha
# Processing Record 22 of Set 16 | atar
# Processing Record 23 of Set 16 | changde
# Processing Record 24 of Set 16 | asaka
# Processing Record 25 of Set 16 | bend
# Processing Record 26 of Set 16 | emerald
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 721

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0                  Suez      EG  29.9737   32.5263     91.00        19
# 1           Clyde River      CA  70.4692  -68.5914     34.03       100
# 2       Haines Junction      CA  60.7522 -137.5108     44.55        93
# 3          Oktyabrskoye      RU  43.0645   44.7417     58.35        93
# 4  Nikolayevsk-Na-Amure      RU  53.1406  140.7300     40.60        95
# 5               Midland      US  31.9974 -102.0779     75.69        75
# 6              Hermanus      ZA -34.4187   19.2345     77.81        43
# 7             Cape Town      ZA -33.9258   18.4232     81.10        23
# 8                Dwarka      IN  22.2394   68.9678     86.27        70
# 9             Busselton      AU -33.6500  115.3333     53.10        78
#
#    Cloudiness  Wind Speed       Description
# 0           0       10.87         clear sky
# 1          90       12.66   overcast clouds
# 2          81        2.30     broken clouds
# 3          90        1.92        light rain
# 4         100        4.70   overcast clouds
# 5          40       18.41  scattered clouds
# 6           7        4.88         clear sky
# 7           0        3.00         clear sky
# 8           0       13.18         clear sky
# 9          21        9.33        few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
